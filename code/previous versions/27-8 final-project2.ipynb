# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
import plotly_express as px

# %%
url="https://raw.githubusercontent.com/YuLe33/Final-Project-df_full_premierleague1/main/data%20set/df_full_premierleague.csv"
data=pd.read_csv(url)
del(data['Unnamed: 0'],data['link_match'])
data["home_win"]=np.nan
data["date"]=pd.to_datetime(data.date)
data=data.sort_values(by="date")
data = data.reset_index(drop=True)
data
# Out:
#      season       date                 home_team             away_team  \
# 0     10/11 2010-08-14               Aston Villa       West Ham United
# 1     10/11 2010-08-14          Bolton Wanderers                Fulham
# 2     10/11 2010-08-14                   Chelsea  West Bromwich Albion
# 3     10/11 2010-08-14                Sunderland       Birmingham City
# 4     10/11 2010-08-14         Tottenham Hotspur       Manchester City
# ...     ...        ...                       ...                   ...
# 4065  20/21 2021-03-06  Brighton and Hove Albion        Leicester City
# 4066  20/21 2021-03-06                   Burnley               Arsenal
# 4067  20/21 2021-03-07      West Bromwich Albion      Newcastle United
# 4068  20/21 2021-03-07                 Liverpool                Fulham
# 4069  20/21 2021-03-07           Manchester City     Manchester United
#
#      result_full result_ht  home_clearances  home_corners  \
# 0            3-0       2-0             24.0          15.0
# 1            0-0       0-0             54.0           4.0
# 2            6-0       2-0             10.0           3.0
# 3            2-2       1-0             49.0           3.0
# 4            0-0       0-0             20.0          10.0
# ...          ...       ...              ...           ...
# 4065         1-2       1-0              5.0           6.0
# 4066         1-1       1-1             16.0           2.0
# 4067         0-0       0-0             21.0           9.0
# 4068         0-1       0-1             13.0           9.0
# 4069         0-2       0-1              7.0           6.0
#
#       home_fouls_conceded  home_offsides  ...  touches_avg_away  \
# 0                    16.0            1.0  ...               NaN
# 1                    11.0            5.0  ...               NaN
# 2                    12.0            3.0  ...               NaN
# 3                    15.0            2.0  ...               NaN
# 4                    13.0            1.0  ...               NaN
# ...                   ...            ...  ...               ...
# 4065                 14.0            4.0  ...             681.5
# 4066                  5.0            2.0  ...             689.1
# 4067                 11.0            1.0  ...             526.8
# 4068                 10.0            3.0  ...             675.7
# 4069                  9.0            0.0  ...             744.0
#
#       yellow_cards_avg_away  goals_scored_ft_avg_away  \
# 0                       NaN                       NaN
# 1                       NaN                       NaN
# 2                       NaN                       NaN
# 3                       NaN                       NaN
# 4                       NaN                       NaN
# ...                     ...                       ...
# 4065                    1.8                      1.70
# 4066                    1.4                      1.31
# 4067                    1.8                      1.04
# 4068                    1.8                      0.78
# 4069                    1.5                      1.96
#
#       goals_conced_ft_avg_away  sg_match_ft_acum_away  \
# 0                          NaN                    NaN
# 1                          NaN                    NaN
# 2                          NaN                    NaN
# 3                          NaN                    NaN
# 4                          NaN                    NaN
# ...                        ...                    ...
# 4065                      1.15                   15.0
# 4066                      1.04                    7.0
# 4067                      1.69                  -17.0
# 4068                      1.22                  -12.0
# 4069                      1.19                   21.0
#
#       goals_scored_ht_avg_away  goals_conced_ht_avg_away  \
# 0                          NaN                       NaN
# 1                          NaN                       NaN
# 2                          NaN                       NaN
# 3                          NaN                       NaN
# 4                          NaN                       NaN
# ...                        ...                       ...
# 4065                      0.78                      0.59
# 4066                      0.65                      0.65
# 4067                      0.35                      0.69
# 4068                      0.37                      0.59
# 4069                      0.81                      0.67
#
#       sg_match_ht_acum_away  performance_acum_away  home_win
# 0                       NaN                    NaN       NaN
# 1                       NaN                    NaN       NaN
# 2                       NaN                    NaN       NaN
# 3                       NaN                    NaN       NaN
# 4                       NaN                    NaN       NaN
# ...                     ...                    ...       ...
# 4065                    5.0                   61.7       NaN
# 4066                    0.0                   47.4       NaN
# 4067                   -9.0                   33.3       NaN
# 4068                   -6.0                   28.4       NaN
# 4069                    4.0                   63.0       NaN
#
# [4070 rows x 113 columns]

# %%
scors = data["result_full"].str.extract("(\d+)-(\d+)")
data["home_win"] =(scors[0]>scors[1]).astype(int)
tie=(scors[0]==scors[1])
tie
data.loc[tie,"home_win"] = -1
data
# Out:
#      season       date                 home_team             away_team  \
# 0     10/11 2010-08-14               Aston Villa       West Ham United
# 1     10/11 2010-08-14          Bolton Wanderers                Fulham
# 2     10/11 2010-08-14                   Chelsea  West Bromwich Albion
# 3     10/11 2010-08-14                Sunderland       Birmingham City
# 4     10/11 2010-08-14         Tottenham Hotspur       Manchester City
# ...     ...        ...                       ...                   ...
# 4065  20/21 2021-03-06  Brighton and Hove Albion        Leicester City
# 4066  20/21 2021-03-06                   Burnley               Arsenal
# 4067  20/21 2021-03-07      West Bromwich Albion      Newcastle United
# 4068  20/21 2021-03-07                 Liverpool                Fulham
# 4069  20/21 2021-03-07           Manchester City     Manchester United
#
#      result_full result_ht  home_clearances  home_corners  \
# 0            3-0       2-0             24.0          15.0
# 1            0-0       0-0             54.0           4.0
# 2            6-0       2-0             10.0           3.0
# 3            2-2       1-0             49.0           3.0
# 4            0-0       0-0             20.0          10.0
# ...          ...       ...              ...           ...
# 4065         1-2       1-0              5.0           6.0
# 4066         1-1       1-1             16.0           2.0
# 4067         0-0       0-0             21.0           9.0
# 4068         0-1       0-1             13.0           9.0
# 4069         0-2       0-1              7.0           6.0
#
#       home_fouls_conceded  home_offsides  ...  touches_avg_away  \
# 0                    16.0            1.0  ...               NaN
# 1                    11.0            5.0  ...               NaN
# 2                    12.0            3.0  ...               NaN
# 3                    15.0            2.0  ...               NaN
# 4                    13.0            1.0  ...               NaN
# ...                   ...            ...  ...               ...
# 4065                 14.0            4.0  ...             681.5
# 4066                  5.0            2.0  ...             689.1
# 4067                 11.0            1.0  ...             526.8
# 4068                 10.0            3.0  ...             675.7
# 4069                  9.0            0.0  ...             744.0
#
#       yellow_cards_avg_away  goals_scored_ft_avg_away  \
# 0                       NaN                       NaN
# 1                       NaN                       NaN
# 2                       NaN                       NaN
# 3                       NaN                       NaN
# 4                       NaN                       NaN
# ...                     ...                       ...
# 4065                    1.8                      1.70
# 4066                    1.4                      1.31
# 4067                    1.8                      1.04
# 4068                    1.8                      0.78
# 4069                    1.5                      1.96
#
#       goals_conced_ft_avg_away  sg_match_ft_acum_away  \
# 0                          NaN                    NaN
# 1                          NaN                    NaN
# 2                          NaN                    NaN
# 3                          NaN                    NaN
# 4                          NaN                    NaN
# ...                        ...                    ...
# 4065                      1.15                   15.0
# 4066                      1.04                    7.0
# 4067                      1.69                  -17.0
# 4068                      1.22                  -12.0
# 4069                      1.19                   21.0
#
#       goals_scored_ht_avg_away  goals_conced_ht_avg_away  \
# 0                          NaN                       NaN
# 1                          NaN                       NaN
# 2                          NaN                       NaN
# 3                          NaN                       NaN
# 4                          NaN                       NaN
# ...                        ...                       ...
# 4065                      0.78                      0.59
# 4066                      0.65                      0.65
# 4067                      0.35                      0.69
# 4068                      0.37                      0.59
# 4069                      0.81                      0.67
#
#       sg_match_ht_acum_away  performance_acum_away  home_win
# 0                       NaN                    NaN         1
# 1                       NaN                    NaN        -1
# 2                       NaN                    NaN         1
# 3                       NaN                    NaN        -1
# 4                       NaN                    NaN        -1
# ...                     ...                    ...       ...
# 4065                    5.0                   61.7         0
# 4066                    0.0                   47.4        -1
# 4067                   -9.0                   33.3        -1
# 4068                   -6.0                   28.4         0
# 4069                    4.0                   63.0         0
#
# [4070 rows x 113 columns]

# %%
data[["season","date","home_team","away_team","result_ht","home_win"]]
# Out:
#      season       date                 home_team             away_team  \
# 0     10/11 2010-08-14               Aston Villa       West Ham United
# 1     10/11 2010-08-14          Bolton Wanderers                Fulham
# 2     10/11 2010-08-14                   Chelsea  West Bromwich Albion
# 3     10/11 2010-08-14                Sunderland       Birmingham City
# 4     10/11 2010-08-14         Tottenham Hotspur       Manchester City
# ...     ...        ...                       ...                   ...
# 4065  20/21 2021-03-06  Brighton and Hove Albion        Leicester City
# 4066  20/21 2021-03-06                   Burnley               Arsenal
# 4067  20/21 2021-03-07      West Bromwich Albion      Newcastle United
# 4068  20/21 2021-03-07                 Liverpool                Fulham
# 4069  20/21 2021-03-07           Manchester City     Manchester United
#
#      result_ht  home_win
# 0          2-0         1
# 1          0-0        -1
# 2          2-0         1
# 3          1-0        -1
# 4          0-0        -1
# ...        ...       ...
# 4065       1-0         0
# 4066       1-1        -1
# 4067       0-0        -1
# 4068       0-1         0
# 4069       0-1         0
#
# [4070 rows x 6 columns]

# %%
home, away = data['result_full'].str.split('-',1).str
data['home_goals'] = home
data['away_goals'] = away
data['home_goals'] = data['home_goals'].astype(int)
data['away_goals'] = data['away_goals'].astype(int)
# Out:
# C:\Users\laser\AppData\Local\Temp/ipykernel_42744/3713876565.py:1: FutureWarning:
#
# Columnar iteration over characters will be deprecated in future releases.

# %%
data['home_win_score'] = (data.loc[:,'home_goals']-data.loc[:,'away_goals'])>0
data['away_win_score'] = (data.loc[:,'away_goals']-data.loc[:,'home_goals'])>0
data['home_win_score'] = data['home_win_score'].astype(int)
data['away_win_score'] = data['away_win_score'].astype(int)

# %%
total_home_goals = data.groupby('home_team')['home_goals'].sum().sort_values(ascending=False).reset_index()
# total_home_goals
sketch = px.bar(total_home_goals.head(15),x='home_team', y='home_goals',color='home_team')
sketch.update_layout(title='Most Home Goals since 10/11',xaxis_title='Team',yaxis_title='Goals')
sketch.show()

# %%
total_away_goals = data.groupby('away_team')['away_goals'].sum().sort_values(ascending=False).reset_index()
# total_away_goals
sketch_2 = px.bar(total_away_goals.head(15),x='away_team',y='away_goals',color='away_team')
sketch_2.update_layout(title='Most Away Goals sincs 10/11',xaxis_title='Team',yaxis_title='Goals')
sketch_2.show()

# %%
total_home_wins = data.groupby('home_team')['home_win_score'].sum().sort_values(ascending=False).reset_index()
# total_home_wins 
home_wins_sketch = px.bar(total_home_wins.head(15),x='home_team',y='home_win_score',color='home_team')
home_wins_sketch.update_layout(title='Most Home Wins since 10/11',xaxis_title='Team',yaxis_title='Wins')
home_wins_sketch.show()

# %%
total_away_wins = data.groupby('away_team')['away_win_score'].sum().sort_values(ascending=False).reset_index()
# total_away_wins
away_wins_sketch = px.bar(total_away_wins.head(15),x='away_team',y='away_win_score',color='away_team')
away_wins_sketch.update_layout(title='Most Away Wins since 10/11',xaxis_title='Team',yaxis_title='Wins')
away_wins_sketch.show()

# %%
home=data["home_win"].value_counts().plot.pie(autopct='%1.1f%%')

# %% [markdown]
# last games before covid 19 arrive to England:

# %%
#data[data.loc[:,"date"]=="2020-3"]

# %%
before_covid=data.iloc[0:3697]

# %%
before_covid["home_win"].value_counts().plot.pie(autopct='%1.1f%%')
# Out:
# <AxesSubplot:ylabel='home_win'>

# %% [markdown]
# last game without crowd:

# %%
#data[data.loc[:,"date"]=="2020-11-27"]

# %%
covid_times=data.iloc[3698:3886]

# %%
covid_times["home_win"].value_counts().plot.pie(autopct='%1.1f%%')
# Out:
# <AxesSubplot:ylabel='home_win'>

# %%
data[["season","home_team","goal_away_ht","goal_home_ht"]]
# Out:
#      season                 home_team  goal_away_ht  goal_home_ht
# 0     10/11               Aston Villa             0             2
# 1     10/11          Bolton Wanderers             0             0
# 2     10/11                   Chelsea             0             2
# 3     10/11                Sunderland             0             1
# 4     10/11         Tottenham Hotspur             0             0
# ...     ...                       ...           ...           ...
# 4065  20/21  Brighton and Hove Albion             0             1
# 4066  20/21                   Burnley             1             1
# 4067  20/21      West Bromwich Albion             0             0
# 4068  20/21                 Liverpool             1             0
# 4069  20/21           Manchester City             1             0
#
# [4070 rows x 4 columns]

# %%
s=data.groupby(["home_team"])[["home_shots_on_target","goal_away_ht","goal_home_ht"]].mean()
s
# Out:
#                           home_shots_on_target  goal_away_ht  goal_home_ht
# home_team
# AFC Bournemouth                       4.200000      0.726316      0.610526
# Arsenal                               6.078818      0.458128      0.862069
# Aston Villa                           4.000000      0.655172      0.537931
# Birmingham City                       3.000000      0.368421      0.315789
# Blackburn Rovers                      4.026316      0.500000      0.631579
# Blackpool                             4.368421      1.000000      0.789474
# Bolton Wanderers                      4.842105      0.710526      0.578947
# Brighton and Hove Albion              3.535211      0.591549      0.450704
# Burnley                               3.600000      0.481818      0.500000
# Cardiff City                          3.657895      0.894737      0.368421
# Chelsea                               6.384236      0.359606      0.965517
# Crystal Palace                        4.006849      0.595890      0.465753
# Everton                               4.965517      0.467980      0.748768
# Fulham                                4.990826      0.733945      0.559633
# Huddersfield Town                     2.947368      0.789474      0.368421
# Hull City                             3.894737      0.578947      0.561404
# Leeds United                          5.461538      0.769231      0.461538
# Leicester City                        4.503937      0.496063      0.685039
# Liverpool                             6.348039      0.352941      1.029412
# Manchester City                       6.760976      0.312195      1.097561
# Manchester United                     5.876847      0.310345      0.970443
# Middlesbrough                         3.105263      0.578947      0.473684
# Newcastle United                      4.521739      0.559783      0.576087
# Norwich City                          4.000000      0.578947      0.526316
# Queens Park Rangers                   4.438596      0.614035      0.421053
# Reading                               3.473684      1.000000      0.368421
# Sheffield United                      3.529412      0.470588      0.441176
# Southampton                           4.751515      0.551515      0.690909
# Stoke City                            3.776316      0.526316      0.611842
# Sunderland                            3.706767      0.624060      0.541353
# Swansea City                          4.278195      0.571429      0.548872
# Tottenham Hotspur                     5.975369      0.394089      0.817734
# Watford                               3.884211      0.694737      0.421053
# West Bromwich Albion                  4.041916      0.700599      0.574850
# West Ham United                       4.413043      0.565217      0.646739
# Wigan Athletic                        4.824561      0.842105      0.526316
# Wolverhampton Wanderers               4.348315      0.662921      0.528090

# %%
sns.regplot(x='home_shots_on_target', y='goal_home_ht', data=s);
