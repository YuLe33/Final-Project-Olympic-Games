# %%
import pandas as pd
import numpy as np

# %%
url="https://raw.githubusercontent.com/YuLe33/Final-Project-df_full_premierleague/main/data%20set/df_full_premierleague.csv"
data=pd.read_csv(url, encoding='latin1')
data=data.rename(columns={"ï»¿season":"season"})
data
# Out:
#          season        date          home_team                 away_team  \
# 0     2011/2012  01/11/2010          Blackpool      West Bromwich Albion
# 1     2011/2012  11/04/2011          Liverpool           Manchester City
# 2     2011/2012  13/12/2010  Manchester United                   Arsenal
# 3     2011/2012  13/09/2010         Stoke City               Aston Villa
# 4     2011/2012  14/02/2011             Fulham                   Chelsea
# ...         ...         ...                ...                       ...
# 4065  2020/2021  03/02/2021          Liverpool  Brighton and Hove Albion
# 4066  2020/2021  03/03/2021            Burnley            Leicester City
# 4067  2020/2021  03/03/2021     Crystal Palace         Manchester United
# 4068  2020/2021  03/03/2021   Sheffield United               Aston Villa
# 4069  2020/2021  30/12/2020   Newcastle United                 Liverpool
#
#      result_full result_ht  home_clearances  home_corners  \
# ...

# %%
data=data[data["result_full"].str.contains("-")]

# %%
data.loc[data.result_full=="44197"]
# Out:
# Empty DataFrame
# ...

# %%
data
# Out:
#          season        date          home_team                 away_team  \
# 1     2011/2012  11/04/2011          Liverpool           Manchester City
# 2     2011/2012  13/12/2010  Manchester United                   Arsenal
# 4     2011/2012  14/02/2011             Fulham                   Chelsea
# 5     2011/2012  16/08/2010  Manchester United          Newcastle United
# 6     2011/2012  18/10/2010   Blackburn Rovers                Sunderland
# ...         ...         ...                ...                       ...
# 4063  2020/2021  03/02/2021             Fulham            Leicester City
# 4065  2020/2021  03/02/2021          Liverpool  Brighton and Hove Albion
# 4067  2020/2021  03/03/2021     Crystal Palace         Manchester United
# 4068  2020/2021  03/03/2021   Sheffield United               Aston Villa
# 4069  2020/2021  30/12/2020   Newcastle United                 Liverpool
#
#      result_full result_ht  home_clearances  home_corners  \
# ...
